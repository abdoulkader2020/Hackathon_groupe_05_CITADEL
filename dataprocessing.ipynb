# %%
import pandas as pd
import numpy as np
import os

# %%
file_path = os.path.join(os.getcwd(), "dataset/dataset_lien_le_fasonet.json")

# %%
data = pd.read_json(file_path)

# %%
data.head(10)
# Out:
#                                             Comments  \
# 0  [{'Comment': 'On est tant pressé pourquoi ? Le...
# 1  [{'Comment': 'Depuis 2015 on se demande pourqu...
# 2                                                 []
# 3  [{'Comment': 'Question : est-ce le même qui av...
# 4  [{'Comment': 'La population est avec l’armée, ...
# 5  [{'Comment': '41 terroristes neutralisés et au...
# 6  [{'Comment': 'Les autorités nationales ou loca...
# 7  [{'Comment': 'Paix aux ames des disparus.Promp...
# 8  [{'Comment': 'Merci aux fds, vdp et autres qui...
# 9  [{'Comment': 'Ceci veut-il dire que le patron ...
#
#                                              Content    Publish_by  \
# 0  Par ailleurs, il a été établi un point sur la ...
# 1  Dans le rapport mené par les experts de Crisis...
# 2  « Problématique de l’accès aux produits et ser...
# 3  Camouflés dans une ambulance et en binômes sur...  Source : AIB
# 4  Au cours d’intenses combats qui ont duré plus ...
# ...

# %%
data.describe()
# Out:
#        Comments Content Publish_by          Publish_date  \
# count      1820    1820       1820                  1820
# unique     1646    1644         38                  1796
# top          []      \n             2016-01-18T23:30:00Z
# freq        175     134       1769                     3
#
#                                                     Title
# count                                                1820
# unique                                               1819
# top     Attaques terroristes : Le CEDDH appelle à la s...
# freq                                                    2

# %%
file_path = os.path.join(os.getcwd(), "dataset\Western_Africa-Burkina_Faso_acled.csv")

# %%
row_df_acled = pd.read_csv(file_path,delimiter=";")

# %%
for i in row_df_acled.columns:
    print(i)
# Out:
# data_id
# iso
# event_id_cnty
# event_id_no_cnty
# event_date
# year
# time_precision
# event_type
# sub_event_type
# actor1
# assoc_actor_1
# inter1
# interaction
# region
# country
# admin1
# admin2
# admin3
# location
# latitude
# longitude
# geo_precision
# source
# source_scale
# notes
# fatalities
# timestamp
# iso3

# %%
row_df_acled.describe()
# Out:
#             data_id     iso  event_id_no_cnty         year  time_precision  \
# count  9.479000e+03  9479.0       9479.000000  9479.000000     9479.000000
# mean   8.706497e+06   854.0       5645.661251  2021.139783        1.058128
# std    4.984513e+05     0.0       1505.494987     0.862564        0.249704
# min    6.714201e+06   854.0       2018.000000  2019.000000        1.000000
# 25%    8.166582e+06   854.0       4426.500000  2021.000000        1.000000
# 50%    8.706178e+06   854.0       5685.000000  2021.000000        1.000000
# 75%    9.166677e+06   854.0       6927.500000  2022.000000        1.000000
# max    9.490492e+06   854.0       8163.000000  2022.000000        3.000000
#
#             inter1  interaction     latitude    longitude  geo_precision  \
# count  9479.000000  9479.000000  9479.000000  9479.000000    9479.000000
# mean      3.552590    24.323030    13.063541    -0.907689       1.410803
# ...

# %%
df_acled = row_df_acled.drop(['assoc_actor_1','inter1' , 'interaction' ,'region' ,'country' ,'geo_precision','iso3' ,'iso' ,'data_id','event_id_cnty','event_id_no_cnty','event_date','time_precision'],axis=1)

# %%
df_acled.head()
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty         event_date  year  \
# 0  9487832  854       BFO8142              8142  15 September 2022  2022
# 1  9487832  854       BFO8142              8142  15 September 2022  2022
# 2  9487834  854       BFO8155              8155  15 September 2022  2022
# 3  9487834  854       BFO8155              8155  15 September 2022  2022
# 4  9487835  854       BFO8156              8156  15 September 2022  2022
#
#    time_precision              event_type                sub_event_type  \
# 0               1  Strategic developments  Looting/property destruction
# 1               1  Strategic developments  Looting/property destruction
# 2               1  Strategic developments  Looting/property destruction
# 3               1  Strategic developments  Looting/property destruction
# 4               1  Strategic developments  Looting/property destruction
#
#                                          actor1  ...      admin2   admin3  \
# ...

# %%
df_acled['actor1']
# Out:
# 0            JNIM: Group for Support of Islam and Muslims
# 1                                Civilians (Burkina Faso)
# 2            JNIM: Group for Support of Islam and Muslims
# 3                                Civilians (Burkina Faso)
# 4            JNIM: Group for Support of Islam and Muslims
#                               ...
# 9474    Islamic State (West Africa) - Greater Sahara F...
# 9475         JNIM: Group for Support of Islam and Muslims
# 9476              Military Forces of Burkina Faso (2015-)
# 9477         JNIM: Group for Support of Islam and Muslims
# 9478                             Civilians (Burkina Faso)
# Name: actor1, Length: 9479, dtype: object

# %%
datas.head(20)
# Out:
#     data_id  iso event_id_cnty  event_id_no_cnty         event_date  year  \
# 0   9487832  854       BFO8142              8142  15 September 2022  2022
# 1   9487832  854       BFO8142              8142  15 September 2022  2022
# 2   9487834  854       BFO8155              8155  15 September 2022  2022
# 3   9487834  854       BFO8155              8155  15 September 2022  2022
# 4   9487835  854       BFO8156              8156  15 September 2022  2022
# 5   9487835  854       BFO8156              8156  15 September 2022  2022
# 6   9487998  854       BFO8133              8133  15 September 2022  2022
# 7   9487998  854       BFO8133              8133  15 September 2022  2022
# 8   9487817  854       BFO8110              8110  14 September 2022  2022
# 9   9487817  854       BFO8110              8110  14 September 2022  2022
# 10  9487824  854       BFO8124              8124  14 September 2022  2022
# 11  9487824  854       BFO8124              8124  14 September 2022  2022
# ...
